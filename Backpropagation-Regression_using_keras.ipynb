# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuskaghosh/Anuskaghosh/blob/main/Backpropagation-Regression_using_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[8,8,1],[7,9,1],[6,10,0],[5,5,0]], columns=['cgpa', 'profile_score','lpa'])

# %%
df.head()
# Out:
#    cgpa  profile_score  placed
# 0     8              8       1
# 1     7              9       1
# 2     6             10       0
# 3     5              5       0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['cgpa'].plot(kind='hist', bins=20, title='cgpa')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['profile_score'].plot(kind='hist', bins=20, title='profile_score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['placed'].plot(kind='hist', bins=20, title='placed')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(2, activation = 'linear', input_dim = 2))
model.add(Dense(1, activation = 'linear'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                      │ (None, 2)                   │               6 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               3 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.get_weights()
# Out:
# [array([[-0.04265296,  0.48569798],
#         [-0.0253464 , -0.71220267]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.7442459 ],
#         [0.60634005]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
new_weights = [np.array([[0.1 , 0.1],
                         [0.1 , 0.1]], dtype=np.float32),
               np.array([0.,0.], dtype=np.float32),
               np.array([[0.1],[0.1]], dtype=np.float32),
               np.array([0.], dtype=np.float32)]

# %%
model.set_weights(new_weights)

# %%
from tensorflow import keras

# Corrected optimizer reference
optimizer = keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='mean_squared_error', optimizer=optimizer)

# %%
print(df.columns)
# Out:
# Index(['cgpa', 'profile_score', 'lpa'], dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns.tolist())
# Out:
# ['cgpa', 'profile_score', 'lpa']

# %%
model.fit(df.iloc[:, 0:-1].values, df['lpa'].values, epochs=75, verbose=1, batch_size=1)
df.rename(columns={'LPA_score': 'lpa'}, inplace=True)
# Out:
# Epoch 1/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3237
# Epoch 2/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3454
# Epoch 3/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1962
# Epoch 4/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2176
# Epoch 5/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3106
# Epoch 6/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3046
# Epoch 7/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2589
# Epoch 8/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2691
# Epoch 9/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2721
# Epoch 10/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2398
# Epoch 11/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1726
# Epoch 12/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1972
# Epoch 13/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1740
# Epoch 14/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1857
# Epoch 15/75
# ...

# %%
model.get_weights()
# Out:
# [array([[0.15118618, 0.15118618],
#         [0.11894046, 0.11894046]], dtype=float32),
#  array([0.01113593, 0.01113593], dtype=float32),
#  array([[0.13409783],
#         [0.13409783]], dtype=float32),
#  array([0.01140391], dtype=float32)]
